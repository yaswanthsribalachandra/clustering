# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn  as sns
import pandas as pd

# %%
df = pd.read_excel('Insurance_Customers_data.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458872 entries, 0 to 458871
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Application_Nr       458862 non-null  object
#  1   QuoteGeneratedDate   458872 non-null  datetime64[ns]
#  2   OfferCoverageAmount  458872 non-null  int64
#  3   Offer_Stat_Desc      458872 non-null  object
#  4   OfferPremiumAmount   458872 non-null  float64
#  5   OfferBillingMethod   458872 non-null  object
#  6   Pmnt_Freq_Desc       458832 non-null  object
#  7   Effective_Date       190605 non-null  datetime64[ns]
#  8   Paid_To_Date         190605 non-null  datetime64[ns]
#  9   Offered_NAP          458872 non-null  float64
#  10  Issued_NAP           190605 non-null  float64
#  11  CurrentBillMethod    190605 non-null  object
#  12  ProductType          458862 non-null  object
#  13  Age_at_AppReceived   400627 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   QuoteGeneratedDate  OfferCoverageAmount  OfferPremiumAmount  \
# count                         458872        458872.000000       458872.000000
# mean   2021-05-29 14:39:36.317578240         41713.013651           75.453247
# min              2018-02-07 00:00:00          1000.000000            0.000000
# 25%              2020-12-02 00:00:00         10000.000000           40.500000
# 50%              2021-07-19 00:00:00         20000.000000           57.300000
# 75%              2022-02-03 00:00:00         45000.000000           90.700000
# max              2022-09-07 00:00:00        300000.000000         5124.000000
# std                              NaN         61338.126792           68.232138
#
#                       Effective_Date                   Paid_To_Date  \
# count                         190605                         190605
# mean   2021-05-09 20:43:12.611946240  2021-12-18 12:22:37.840559872
# ...

# %%
df.head()
# Out:
#   Application_Nr QuoteGeneratedDate  OfferCoverageAmount Offer_Stat_Desc  \
# 0   CUNA11261506         2018-02-07                15000            Void
# 1   CUNA11263501         2018-02-08                10000          Signed
# 2   CUNA11264400         2018-02-09                15000          Signed
# 3   CUNA11264436         2018-02-09                15000          Signed
# 4   CUNA11264525         2018-02-09                10000          Signed
#
#    OfferPremiumAmount OfferBillingMethod Pmnt_Freq_Desc Effective_Date  \
# 0               13.75        Credit Card        Monthly            NaT
# 1               74.80        Credit Card        Monthly     2018-02-08
# 2               42.35        Credit Card        Monthly     2018-02-09
# 3               57.05        Credit Card        Monthly     2018-02-09
# 4               27.80            ACH/PAC        Monthly     2018-02-12
#
#   Paid_To_Date  Offered_NAP  Issued_NAP CurrentBillMethod     ProductType  \
# ...

# %%
df.drop(['Application_Nr'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   QuoteGeneratedDate  OfferCoverageAmount Offer_Stat_Desc  OfferPremiumAmount  \
# 0         2018-02-07                15000            Void               13.75
# 1         2018-02-08                10000          Signed               74.80
# 2         2018-02-09                15000          Signed               42.35
# 3         2018-02-09                15000          Signed               57.05
# 4         2018-02-09                10000          Signed               27.80
#
#   OfferBillingMethod Pmnt_Freq_Desc Effective_Date Paid_To_Date  Offered_NAP  \
# 0        Credit Card        Monthly            NaT          NaT        165.0
# 1        Credit Card        Monthly     2018-02-08   2022-09-08        897.6
# 2        Credit Card        Monthly     2018-02-09   2022-10-09        508.2
# 3        Credit Card        Monthly     2018-02-09   2022-10-09        684.6
# 4            ACH/PAC        Monthly     2018-02-12   2021-02-12        333.6
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458872 entries, 0 to 458871
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   QuoteGeneratedDate   458872 non-null  datetime64[ns]
#  1   OfferCoverageAmount  458872 non-null  int64
#  2   Offer_Stat_Desc      458872 non-null  object
#  3   OfferPremiumAmount   458872 non-null  float64
#  4   OfferBillingMethod   458872 non-null  object
#  5   Pmnt_Freq_Desc       458832 non-null  object
#  6   Effective_Date       190605 non-null  datetime64[ns]
#  7   Paid_To_Date         190605 non-null  datetime64[ns]
#  8   Offered_NAP          458872 non-null  float64
#  9   Issued_NAP           190605 non-null  float64
#  10  CurrentBillMethod    190605 non-null  object
#  11  ProductType          458862 non-null  object
#  12  Age_at_AppReceived   400627 non-null  float64
#  13  PartnerMarker        458872 non-null  object
# ...

# %%
df.drop(['QuoteGeneratedDate'], axis=1, inplace=True)

# %%
df.drop(['Effective_Date'], axis=1, inplace=True)

# %%
df.drop(['Paid_To_Date'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458872 entries, 0 to 458871
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   OfferCoverageAmount  458872 non-null  int64
#  1   Offer_Stat_Desc      458872 non-null  object
#  2   OfferPremiumAmount   458872 non-null  float64
#  3   OfferBillingMethod   458872 non-null  object
#  4   Pmnt_Freq_Desc       458832 non-null  object
#  5   Offered_NAP          458872 non-null  float64
#  6   Issued_NAP           190605 non-null  float64
#  7   CurrentBillMethod    190605 non-null  object
#  8   ProductType          458862 non-null  object
#  9   Age_at_AppReceived   400627 non-null  float64
#  10  PartnerMarker        458872 non-null  object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 38.5+ MB

# %%
df.describe(
    include='all'
)
# Out:
#         OfferCoverageAmount Offer_Stat_Desc  OfferPremiumAmount  \
# count         458872.000000          458872       458872.000000
# unique                  NaN              20                 NaN
# top                     NaN          Signed                 NaN
# freq                    NaN          165207                 NaN
# mean           41713.013651             NaN           75.453247
# std            61338.126792             NaN           68.232138
# min             1000.000000             NaN            0.000000
# 25%            10000.000000             NaN           40.500000
# 50%            20000.000000             NaN           57.300000
# 75%            45000.000000             NaN           90.700000
# max           300000.000000             NaN         5124.000000
#
#        OfferBillingMethod Pmnt_Freq_Desc    Offered_NAP     Issued_NAP  \
# count              458872         458832  458872.000000  190605.000000
# ...

# %%
df.shape
# Out:
# (458872, 11)

# %%
df.isna().sum()
# Out:
# OfferCoverageAmount         0
# Offer_Stat_Desc             0
# OfferPremiumAmount          0
# OfferBillingMethod          0
# Pmnt_Freq_Desc             40
# Offered_NAP                 0
# Issued_NAP             268267
# CurrentBillMethod      268267
# ProductType                10
# Age_at_AppReceived      58245
# PartnerMarker               0
# dtype: int64

# %%
df.drop(['Issued_NAP'], axis=1, inplace=True)

# %%
df.drop(['CurrentBillMethod'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    OfferCoverageAmount Offer_Stat_Desc  OfferPremiumAmount OfferBillingMethod  \
# 0                15000            Void               13.75        Credit Card
# 1                10000          Signed               74.80        Credit Card
# 2                15000          Signed               42.35        Credit Card
# 3                15000          Signed               57.05        Credit Card
# 4                10000          Signed               27.80            ACH/PAC
#
#   Pmnt_Freq_Desc  Offered_NAP     ProductType  Age_at_AppReceived  \
# 0        Monthly        165.0  SI Term Band 1                53.0
# 1        Monthly        897.6   SI Whole Life                70.0
# 2        Monthly        508.2   SI Whole Life                54.0
# 3        Monthly        684.6   SI Whole Life                58.0
# 4        Monthly        333.6  SI Term Band 1                65.0
#
#   PartnerMarker
# 0       Liberty
# 1       Liberty
# 2       Liberty
# 3       Liberty
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458872 entries, 0 to 458871
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   OfferCoverageAmount  458872 non-null  int64
#  1   Offer_Stat_Desc      458872 non-null  object
#  2   OfferPremiumAmount   458872 non-null  float64
#  3   OfferBillingMethod   458872 non-null  object
#  4   Pmnt_Freq_Desc       458832 non-null  object
#  5   Offered_NAP          458872 non-null  float64
#  6   ProductType          458862 non-null  object
#  7   Age_at_AppReceived   400627 non-null  float64
#  8   PartnerMarker        458872 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 31.5+ MB

# %%
df['Offer_Stat_Desc'].value_counts()
# Out:
# Offer_Stat_Desc
# Signed                             165207
# Abandoned                           97816
# Declined                            81451
# Lapsed Abandoned                    48129
# Carrier declined to issue           25804
# Approved                            25390
# Closed                               5335
# In Progress                          4374
# Void                                 4370
# Consumer Invited                      424
# Pending                               259
# Coverage Maxed Out                    198
# Waiting for vSig Audio                 48
# Closed - Suspected Fraud               35
# Closed - Suspected Fraud-Letter        13
# Unknown                                 7
# Signed -Pending Decision                6
# Completed/Sent                          3
# Pending signature                       2
# Waiting for signed PDF                  1
# Name: count, dtype: int64

# %%
df['Pmnt_Freq_Desc'].value_counts()
# Out:
# Pmnt_Freq_Desc
# Monthly           457267
# Quarterly            775
# Annual               486
# Semi-Annual          294
# Not Applicable        10
# Name: count, dtype: int64

# %%
df['OfferBillingMethod'].value_counts()
# Out:
# OfferBillingMethod
# ACH/PAC        329659
# Credit Card    127057
# Direct Bill      2132
# Unknown            17
# List Bill           7
# Name: count, dtype: int64

# %%
df['ProductType'].value_counts()
# Out:
# ProductType
# SI Whole Life     312810
# SI Term Band 1     70821
# SI Term Band 2     37344
# TAWL               20514
# GAWL               17373
# Name: count, dtype: int64

# %%
df['PartnerMarker'].value_counts()
# Out:
# PartnerMarker
# SelectQuote    228262
# Liberty         97055
# Ethos           95845
# HealthIQ        32852
# AccuQuote        3535
# Quote.com         601
# Sproutt           559
# Coverance         151
# NoExam             12
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    OfferCoverageAmount Offer_Stat_Desc  OfferPremiumAmount OfferBillingMethod  \
# 0                15000            Void               13.75        Credit Card
# 1                10000          Signed               74.80        Credit Card
# 2                15000          Signed               42.35        Credit Card
# 3                15000          Signed               57.05        Credit Card
# 4                10000          Signed               27.80            ACH/PAC
#
#   Pmnt_Freq_Desc  Offered_NAP     ProductType  Age_at_AppReceived  \
# 0        Monthly        165.0  SI Term Band 1                53.0
# 1        Monthly        897.6   SI Whole Life                70.0
# 2        Monthly        508.2   SI Whole Life                54.0
# 3        Monthly        684.6   SI Whole Life                58.0
# 4        Monthly        333.6  SI Term Band 1                65.0
#
#   PartnerMarker
# 0       Liberty
# 1       Liberty
# 2       Liberty
# 3       Liberty
# ...

# %%
df.head()
# Out:
#    OfferCoverageAmount Offer_Stat_Desc  OfferPremiumAmount OfferBillingMethod  \
# 0                15000            Void               13.75        Credit Card
# 1                10000          Signed               74.80        Credit Card
# 2                15000          Signed               42.35        Credit Card
# 3                15000          Signed               57.05        Credit Card
# 4                10000          Signed               27.80            ACH/PAC
#
#   Pmnt_Freq_Desc  Offered_NAP     ProductType  Age_at_AppReceived  \
# 0        Monthly        165.0  SI Term Band 1                53.0
# 1        Monthly        897.6   SI Whole Life                70.0
# 2        Monthly        508.2   SI Whole Life                54.0
# 3        Monthly        684.6   SI Whole Life                58.0
# 4        Monthly        333.6  SI Term Band 1                65.0
#
#   PartnerMarker
# 0       Liberty
# 1       Liberty
# 2       Liberty
# 3       Liberty
# ...

# %%
from sklearn.preprocessing import LabelEncoder

df['Offer_Stat_Desc_encoded'] = LabelEncoder().fit_transform(df['Offer_Stat_Desc'])

# %%
df['OfferBillingMethod_encoded'] = LabelEncoder().fit_transform(df['OfferBillingMethod'])

# %%
df['pmnt_freq_desc_encoded'] = LabelEncoder().fit_transform(df['Pmnt_Freq_Desc'])

# %%
df['ProductType_encoded'] = LabelEncoder().fit_transform(df['ProductType'])

# %%
df['PartnerMarker_encoded'] = LabelEncoder().fit_transform(df['PartnerMarker'])

# %%
df.head()
# Out:
#    OfferCoverageAmount Offer_Stat_Desc  OfferPremiumAmount OfferBillingMethod  \
# 0                15000            Void               13.75        Credit Card
# 1                10000          Signed               74.80        Credit Card
# 2                15000          Signed               42.35        Credit Card
# 3                15000          Signed               57.05        Credit Card
# 4                10000          Signed               27.80            ACH/PAC
#
#   Pmnt_Freq_Desc  Offered_NAP     ProductType  Age_at_AppReceived  \
# 0        Monthly        165.0  SI Term Band 1                53.0
# 1        Monthly        897.6   SI Whole Life                70.0
# 2        Monthly        508.2   SI Whole Life                54.0
# 3        Monthly        684.6   SI Whole Life                58.0
# 4        Monthly        333.6  SI Term Band 1                65.0
#
#   PartnerMarker  Offer_Stat_Desc_encoded  OfferBillingMethod_encoded  \
# ...

# %%
df_with_labels = df.copy()

# %%
df_with_labels.head()
# Out:
#    OfferCoverageAmount Offer_Stat_Desc  OfferPremiumAmount OfferBillingMethod  \
# 0                15000            Void               13.75        Credit Card
# 1                10000          Signed               74.80        Credit Card
# 2                15000          Signed               42.35        Credit Card
# 3                15000          Signed               57.05        Credit Card
# 4                10000          Signed               27.80            ACH/PAC
#
#   Pmnt_Freq_Desc  Offered_NAP     ProductType  Age_at_AppReceived  \
# 0        Monthly        165.0  SI Term Band 1                53.0
# 1        Monthly        897.6   SI Whole Life                70.0
# 2        Monthly        508.2   SI Whole Life                54.0
# 3        Monthly        684.6   SI Whole Life                58.0
# 4        Monthly        333.6  SI Term Band 1                65.0
#
#   PartnerMarker  Offer_Stat_Desc_encoded  OfferBillingMethod_encoded  \
# ...

# %%
df_with_labels.drop(['Offer_Stat_Desc', 'OfferBillingMethod', 'Pmnt_Freq_Desc', 'ProductType', 'PartnerMarker'], axis=1, inplace=True)

# %%
df_with_labels.head()
# Out:
#    OfferCoverageAmount  OfferPremiumAmount  Offered_NAP  Age_at_AppReceived  \
# 0                15000               13.75        165.0                53.0
# 1                10000               74.80        897.6                70.0
# 2                15000               42.35        508.2                54.0
# 3                15000               57.05        684.6                58.0
# 4                10000               27.80        333.6                65.0
#
#    Offer_Stat_Desc_encoded  OfferBillingMethod_encoded  \
# 0                       17                           1
# 1                       14                           1
# 2                       14                           1
# 3                       14                           1
# 4                       14                           0
#
#    pmnt_freq_desc_encoded  ProductType_encoded  PartnerMarker_encoded
# 0                       1                    1                      4
# ...

# %%
df_with_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458872 entries, 0 to 458871
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   OfferCoverageAmount         458872 non-null  int64
#  1   OfferPremiumAmount          458872 non-null  float64
#  2   Offered_NAP                 458872 non-null  float64
#  3   Age_at_AppReceived          400627 non-null  float64
#  4   Offer_Stat_Desc_encoded     458872 non-null  int64
#  5   OfferBillingMethod_encoded  458872 non-null  int64
#  6   pmnt_freq_desc_encoded      458872 non-null  int64
#  7   ProductType_encoded         458872 non-null  int64
#  8   PartnerMarker_encoded       458872 non-null  int64
# dtypes: float64(3), int64(6)
# memory usage: 31.5 MB

# %%
df.shape
# Out:
# (458872, 14)

# %%
df_with_labels.isna().sum()
# Out:
# OfferCoverageAmount               0
# OfferPremiumAmount                0
# Offered_NAP                       0
# Age_at_AppReceived            58245
# Offer_Stat_Desc_encoded           0
# OfferBillingMethod_encoded        0
# pmnt_freq_desc_encoded            0
# ProductType_encoded               0
# PartnerMarker_encoded             0
# dtype: int64

# %%
df_with_labels['Age_at_AppReceived'].fillna(df_with_labels['Age_at_AppReceived'].mean(), inplace=True)
# Out:
# /var/folders/01/lklhpss12y11p3wyssjwlf_40000gn/T/ipykernel_4410/3799764833.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_with_labels['Age_at_AppReceived'].fillna(df_with_labels['Age_at_AppReceived'].mean(), inplace=True)

# %%
df_with_labels.isna().sum()
# Out:
# OfferCoverageAmount           0
# OfferPremiumAmount            0
# Offered_NAP                   0
# Age_at_AppReceived            0
# Offer_Stat_Desc_encoded       0
# OfferBillingMethod_encoded    0
# pmnt_freq_desc_encoded        0
# ProductType_encoded           0
# PartnerMarker_encoded         0
# dtype: int64

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []

# Try different K values
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(df_with_labels)   # use df or df[['col1','col2']] if needed
    wcss.append(kmeans.inertia_)  # inertia = WCSS

# Plot the graph
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# Step 1: Scale data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_with_labels)

# Step 2: Try different K values
for k in range(2, 11):  # silhouette needs at least 2 clusters
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(df_scaled)
    
    score = silhouette_score(df_scaled, labels)
    print(f"K = {k}, Silhouette Score = {score}")
scores = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(df_scaled)
    scores.append(silhouette_score(df_scaled, labels))

import matplotlib.pyplot as plt
plt.plot(range(2, 11), scores, marker='o')
plt.title('Silhouette Score vs K')
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 14
#      11     kmeans = KMeans(n_clusters=k, random_state=42)
#      12     labels = kmeans.fit_predict(df_scaled)
# ---> 14     score = silhouette_score(df_scaled, labels)
#      15     print(f"K = {k}, Silhouette Score = {score}")
#      16 scores = []
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Step 1: Scale data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_with_labels)

# Step 2: Apply K-Means
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(df_scaled)

# Step 3: Get results
labels = kmeans.labels_        # cluster assigned to each point
centroids = kmeans.cluster_centers_

# Add cluster column to df
df['Cluster'] = labels

print(df.head())
# Out:
#    OfferCoverageAmount Offer_Stat_Desc  OfferPremiumAmount OfferBillingMethod  \
# 0                15000            Void               13.75        Credit Card
# 1                10000          Signed               74.80        Credit Card
# 2                15000          Signed               42.35        Credit Card
# 3                15000          Signed               57.05        Credit Card
# 4                10000          Signed               27.80            ACH/PAC
#
#   Pmnt_Freq_Desc  Offered_NAP     ProductType  Age_at_AppReceived  \
# 0        Monthly        165.0  SI Term Band 1                53.0
# 1        Monthly        897.6   SI Whole Life                70.0
# 2        Monthly        508.2   SI Whole Life                54.0
# 3        Monthly        684.6   SI Whole Life                58.0
# 4        Monthly        333.6  SI Term Band 1                65.0
#
#   PartnerMarker  Offer_Stat_Desc_encoded  OfferBillingMethod_encoded  \
# ...

# %%
df.head()
# Out:
#    OfferCoverageAmount Offer_Stat_Desc  OfferPremiumAmount OfferBillingMethod  \
# 0                15000            Void               13.75        Credit Card
# 1                10000          Signed               74.80        Credit Card
# 2                15000          Signed               42.35        Credit Card
# 3                15000          Signed               57.05        Credit Card
# 4                10000          Signed               27.80            ACH/PAC
#
#   Pmnt_Freq_Desc  Offered_NAP     ProductType  Age_at_AppReceived  \
# 0        Monthly        165.0  SI Term Band 1                53.0
# 1        Monthly        897.6   SI Whole Life                70.0
# 2        Monthly        508.2   SI Whole Life                54.0
# 3        Monthly        684.6   SI Whole Life                58.0
# 4        Monthly        333.6  SI Term Band 1                65.0
#
#   PartnerMarker  Offer_Stat_Desc_encoded  OfferBillingMethod_encoded  \
# ...

# %%
df['Cluster'].value_counts()
# Out:
# Cluster
# 1    298710
# 0    130180
# 2     29982
# Name: count, dtype: int64
